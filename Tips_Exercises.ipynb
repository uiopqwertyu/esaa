# %% [markdown]
# <a href="https://colab.research.google.com/github/uiopqwertyu/esaa/blob/master/Tips_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd
import numpy as np
import os
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv')

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
tips=tips.iloc[:,1:]

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
ax = plt.subplots()
ax=sns.distplot(tips['total_bill'], kde=False)
ax.set_title('Total Bill HIstogram')
ax.set_xlabel('Tota Bill')
ax.set_ylabel('Frequency')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
ax=plt.subplots()
ax=sns.regplot(x='total_bill', y='tip',data=tips)
ax.set_title('The Scatter Plot between Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
ax=plt.subplots()
ax=sns.scatterplot(x='total_bill', y='tip', size='size',data=tips)
ax.set_title('The Scatter Plot between Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
ax=plt.subplots()
ax=sns.barplot(x=tips['day'],y=tips['total_bill'])
ax.set_title('Total Bill Histogram for Days')
ax.set_xlabel('Days')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
ax=plt.subplots()
ax=sns.scatterplot(x='tip', y='day', hue='sex', data=tips)
ax.set_title('The Scatter Plot between Tips and Days')
ax.set_xlabel('Tip')
ax.set_ylabel('Day')
# Out:
# Text(0, 0.5, 'Day')

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
ax=plt.subplots()
ax=sns.boxplot(x='time',y='total_bill', data=tips)
ax.set_title('The Boxplot between Total Bill and Time')
ax.set_xlabel('Time')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
facet=sns.FacetGrid(tips,col='time')
facet.map(sns.distplot, 'total_bill')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
facet=sns.FacetGrid(tips,col='sex', hue='smoker')
facet.map(plt.scatter, 'total_bill','tip')

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.
